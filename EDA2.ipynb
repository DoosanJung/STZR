# %% [markdown]
# ### Same as EDA

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfs = pickle.load(open('dfs_churn_marked.p'))

# %%
def dropping_col(dfs, col_name):
    if col_name in dfs.columns:
        dfs = dfs.drop(col_name, axis = 1)
    return dfs

drop_col_lst = ['abtm','coiso','gen','mvcp','mvrt','mvsctg','stype','utype','v']
for col in drop_col_lst:
    dfs = dropping_col(dfs,col)

# %%
# Only columns of interest
tmp_dfs = dfs[['ts2','drt','errmsg','mplyevnt','spos','ssid','szrid','tBuf','tIBuf','tLBuf','tPld','tVH','tid','type','uid','churn']]

# %%
tmp_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182000 entries, 0 to 181999
# Data columns (total 16 columns):
# ts2         182000 non-null datetime64[ns]
# drt         182000 non-null int64
# errmsg      2262 non-null object
# mplyevnt    41523 non-null object
# spos        167826 non-null object
# ssid        182000 non-null object
# szrid       182000 non-null object
# tBuf        182000 non-null int64
# tIBuf       182000 non-null int64
# tLBuf       182000 non-null int64
# tPld        182000 non-null int64
# tVH         182000 non-null int64
# tid         182000 non-null object
# type        182000 non-null object
# uid         182000 non-null object
# churn       182000 non-null bool
# dtypes: bool(1), datetime64[ns](1), int64(6), object(8)
# memory usage: 22.4+ MB

# %%
tmp_dfs_rmv_tid_Uns = tmp_dfs[tmp_dfs['tid']!='Unset']
print type(tmp_dfs_rmv_tid_Uns)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
uid_grouped_rmv_tid_Uns = tmp_dfs_rmv_tid_Uns.groupby('uid')

# %%
#for uid in uid_grouped_rmv_tid_Uns.groups.keys():
#    uid_grouped_rmv_tid_Uns.get_group(uid)

# %% [markdown]
# ### Each uid group looks like this...

# %%
uid_lst = uid_grouped_rmv_tid_Uns.groups.keys()
print type(uid_grouped_rmv_tid_Uns.get_group(uid_lst[0]))

# uid_lst[0]
uid_grouped_rmv_tid_Uns.get_group(uid_lst[0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                            ts2      drt errmsg mplyevnt   spos  \
# 6555   2017-04-03 23:57:00.018  3813000    NaN      NaN  V0039
# 26656  2017-04-13 23:45:14.807        0    NaN      NaN  V0051
# 36667  2017-04-18 23:47:56.117        0    NaN      NaN  V0064
# 44113  2017-04-22 23:45:02.299  3410000    NaN    brchg  L2346
# 44360  2017-04-22 23:45:07.305  6010000    NaN    brchg  V0043
# 44958  2017-04-22 23:45:22.322        0    NaN      NaN  V0000
# 45291  2017-04-22 23:45:32.334        0    NaN      NaN  V0008
# 45783  2017-04-22 23:45:42.345        0    NaN      NaN    NaN
# 65922  2017-05-02 23:49:11.109        0    NaN      NaN    NaN
# 84160  2017-05-12 23:52:23.070  2079000    NaN    brchg  V0044
# 85007  2017-05-12 23:52:48.224        0    NaN      NaN  V0062
# 87207  2017-05-13 23:48:07.660        0    NaN      NaN  V0041
# 90601  2017-05-15 23:54:45.794  5153000    NaN      NaN  V0067
# ...

# %%
# uid_lst[1]
uid_grouped_rmv_tid_Uns.get_group(uid_lst[1])
# Out:
#                            ts2      drt errmsg  mplyevnt   spos  \
# 16782  2017-04-08 23:46:17.456        0    NaN       NaN  V0033
# 28854  2017-04-14 23:50:33.747        0    NaN       NaN  V0066
# 28930  2017-04-14 23:50:33.309        0    NaN       NaN  V0028
# 29407  2017-04-14 23:50:50.068        0    NaN       NaN  V0086
# 29465  2017-04-14 23:50:50.071        0    NaN       NaN  V0007
# 50244  2017-04-25 23:47:20.340  1929000    NaN     brchg  V0014
# 50277  2017-04-25 23:47:20.350  1985000    NaN     brchg  V0040
# 50513  2017-04-25 23:47:28.379  3435000    NaN       NaN  V0052
# 126208 2017-06-02 23:51:38.207  3991000    NaN  bufStart  V0030
# 126303 2017-06-02 23:51:38.209  3890000    NaN  bufStart  V0063
# 147604 2017-06-12 23:55:10.072        0    NaN       NaN  V0025
# 172537 2017-06-25 23:53:41.640        0    NaN       NaN  V0015
# 173961 2017-06-25 23:54:30.196        0    NaN       NaN    NaN
#
#                                         ssid  \
# ...

# %% [markdown]
# ### Each tid group within a uid group

# %%
# tid group within uid_lst[0]
uid_tid_grouped_rmv_tid_Uns = uid_grouped_rmv_tid_Uns.get_group(uid_lst[0]).groupby('tid')

# %%
# tids within uid_lst[0]
uid_tid_lst = sorted(uid_tid_grouped_rmv_tid_Uns.groups.keys())

# %%
for tid in uid_tid_lst:
    print tid
# Out:
# 0450b5c2-12b6-46ce-8dc3-5aae2938d04b
# 1f37f46f-bb68-4821-a40b-f04412f322ff
# 2c0ef99a-48dd-4821-bb48-9c80dc16e207
# 3b3cb732-3789-4e13-b27a-ff4be59e54db
# 3f426798-ae28-4cd7-a295-a95cea2e7595
# 46a35a2e-8a9d-4fa5-ac76-a122b4f99dc3
# 4b962d2c-c6cc-4721-b466-0cdb8e2debbc
# 5b88c204-f89c-458a-a93c-27f644c1157f
# 8182a689-8365-4414-9144-c407d2037a16
# a1b704d4-670f-41bc-9f1d-f56029861af5
# adadc397-97b5-4b0d-8fb1-8827342742f6
# cccdd86a-e2da-4592-bcc7-e4faf42b00e1
# d1160e7b-3382-49cc-9438-550087e733f5
# d630fd38-e129-4787-967f-0ecc44608620
# dcf3bbbe-1e55-4a92-9122-83babdb064a0
# f8e660d5-dc0b-4f64-9f27-b96ae90cd188

# %%
# group with uid_lst[0] and uid_tid_lst[0]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[0])
# Out:
#                           ts2  drt errmsg mplyevnt spos  \
# 81805 2017-05-10 23:52:59.633    0    NaN      NaN  NaN
# 81887 2017-05-10 23:52:59.638    0    NaN      NaN  NaN
# 81920 2017-05-10 23:52:59.847    0    NaN      NaN  NaN
#
#                                        ssid  \
# 81805  984ab1d3-0ab9-4dfe-bdaa-021e639cc1ef
# 81887  984ab1d3-0ab9-4dfe-bdaa-021e639cc1ef
# 81920  984ab1d3-0ab9-4dfe-bdaa-021e639cc1ef
#
#                                       szrid  tBuf  tIBuf  tLBuf  tPld  tVH  \
# 81805  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
# 81887  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
# 81920  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
#
#                                         tid       type            uid  churn
# 81805  0450b5c2-12b6-46ce-8dc3-5aae2938d04b         vh  WUCH155102337  False
# 81887  0450b5c2-12b6-46ce-8dc3-5aae2938d04b  mplyevent  WUCH155102337  False
# ...

# %%
#dfs[dfs['tid']=='0450b5c2-12b6-46ce-8dc3-5aae2938d04b']

# %%
# group with uid_lst[0] and uid_tid_lst[1]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[1])
# Out:
#                            ts2  drt errmsg mplyevnt   spos  \
# 178492 2017-06-28 23:58:03.115    0    NaN      NaN  V0057
#
#                                         ssid  \
# 178492  176466f6-e37e-4394-9068-94a6769be355
#
#                                        szrid  tBuf  tIBuf  tLBuf  tPld    tVH  \
# 178492  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0   5004     0  59859
#
#                                          tid type            uid  churn
# 178492  1f37f46f-bb68-4821-a40b-f04412f322ff   vh  WUCH155102337  False

# %%
# group with uid_lst[0] and uid_tid_lst[2]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[2])
# Out:
#                           ts2      drt errmsg mplyevnt   spos  \
# 62355 2017-05-01 23:42:54.847  2980000    NaN    brchg  V0047
#
#                                        ssid  \
# 62355  fc919f3c-544d-4d2a-8d1e-d1406265251f
#
#                                       szrid  tBuf  tIBuf  tLBuf  tPld    tVH  \
# 62355  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0   5003     0  59889
#
#                                         tid type            uid  churn
# 62355  2c0ef99a-48dd-4821-bb48-9c80dc16e207   vh  WUCH155102337  False

# %%
# group with uid_lst[0] and uid_tid_lst[3]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[3])
# Out:
#                           ts2      drt errmsg mplyevnt   spos  \
# 78218 2017-05-09 23:53:40.076  3119000    NaN    brchg  V0038
#
#                                        ssid  \
# 78218  67ae36ea-7bdb-4060-ba66-5dbb5425c72c
#
#                                       szrid  tBuf  tIBuf  tLBuf  tPld    tVH  \
# 78218  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0   5003     0  59864
#
#                                         tid       type            uid  churn
# 78218  3b3cb732-3789-4e13-b27a-ff4be59e54db  mplyevent  WUCH155102337  False

# %%
# group with uid_lst[0] and uid_tid_lst[4]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[4])
# Out:
#                            ts2  drt errmsg mplyevnt   spos  \
# 129610 2017-06-03 23:51:06.561    0    NaN      NaN  V0061
# 129654 2017-06-03 23:51:06.567    0    NaN      NaN  V0031
# 129694 2017-06-03 23:51:05.157    0    NaN      NaN  V0047
#
#                                         ssid  \
# 129610  1cb1b376-457e-4944-9235-febffddd829a
# 129654  1cb1b376-457e-4944-9235-febffddd829a
# 129694  1cb1b376-457e-4944-9235-febffddd829a
#
#                                        szrid  tBuf  tIBuf  tLBuf  tPld  tVH  \
# 129610  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
# 129654  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
# 129694  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
#
#                                          tid       type            uid  churn
# 129610  3f426798-ae28-4cd7-a295-a95cea2e7595  mplyevent  WUCH155102337  False
# 129654  3f426798-ae28-4cd7-a295-a95cea2e7595        Buf  WUCH155102337  False
# ...

# %%
# group with uid_lst[0] and uid_tid_lst[5]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[5])
# Out:
#                            ts2  drt errmsg mplyevnt   spos  \
# 153632 2017-06-15 23:59:09.741    0    NaN      NaN  V0000
#
#                                         ssid  \
# 153632  f0fdf6ef-8f30-4e52-b07d-f0ff4848e396
#
#                                        szrid  tBuf  tIBuf  tLBuf  tPld  tVH  \
# 153632  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
#
#                                          tid type            uid  churn
# 153632  46a35a2e-8a9d-4fa5-ac76-a122b4f99dc3   vh  WUCH155102337  False

# %%
# group with uid_lst[0] and uid_tid_lst[6]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[6])
# Out:
#                            ts2  drt errmsg mplyevnt   spos  \
# 180913 2017-06-29 23:55:59.702    0    NaN      NaN  V0000
#
#                                         ssid  \
# 180913  a0295be0-221e-4b14-966f-8ed542faa6b0
#
#                                        szrid  tBuf  tIBuf  tLBuf  tPld  tVH  \
# 180913  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
#
#                                          tid type            uid  churn
# 180913  4b962d2c-c6cc-4721-b466-0cdb8e2debbc   vh  WUCH155102337  False

# %%
# group with uid_lst[0] and uid_tid_lst[7]
uid_tid_grouped_rmv_tid_Uns.get_group(uid_tid_lst[7])
# Out:
#                           ts2  drt errmsg mplyevnt spos  \
# 85828 2017-05-12 23:52:15.851    0    NaN      NaN  NaN
#
#                                        ssid  \
# 85828  8756683e-1d3f-4128-b534-8840d7adf55c
#
#                                       szrid  tBuf  tIBuf  tLBuf  tPld  tVH  \
# 85828  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
#
#                                         tid type            uid  churn
# 85828  5b88c204-f89c-458a-a93c-27f644c1157f   vh  WUCH155102337  False

# %%
# tids with uid_lst[0]
for tid in uid_tid_lst:
    print tid
# Out:
# 0450b5c2-12b6-46ce-8dc3-5aae2938d04b
# 1f37f46f-bb68-4821-a40b-f04412f322ff
# 2c0ef99a-48dd-4821-bb48-9c80dc16e207
# 3b3cb732-3789-4e13-b27a-ff4be59e54db
# 3f426798-ae28-4cd7-a295-a95cea2e7595
# 46a35a2e-8a9d-4fa5-ac76-a122b4f99dc3
# 4b962d2c-c6cc-4721-b466-0cdb8e2debbc
# 5b88c204-f89c-458a-a93c-27f644c1157f
# 8182a689-8365-4414-9144-c407d2037a16
# a1b704d4-670f-41bc-9f1d-f56029861af5
# adadc397-97b5-4b0d-8fb1-8827342742f6
# cccdd86a-e2da-4592-bcc7-e4faf42b00e1
# d1160e7b-3382-49cc-9438-550087e733f5
# d630fd38-e129-4787-967f-0ecc44608620
# dcf3bbbe-1e55-4a92-9122-83babdb064a0
# f8e660d5-dc0b-4f64-9f27-b96ae90cd188

# %%
# tids with uid_lst[0]
for tid in uid_tid_lst:
    if uid_tid_grouped_rmv_tid_Uns.get_group(tid).shape[0]!=1:
        print uid_tid_grouped_rmv_tid_Uns.get_group(tid)
        print '=='*40
# Out:
#                           ts2  drt errmsg mplyevnt spos  \
# 81805 2017-05-10 23:52:59.633    0    NaN      NaN  NaN
# 81887 2017-05-10 23:52:59.638    0    NaN      NaN  NaN
# 81920 2017-05-10 23:52:59.847    0    NaN      NaN  NaN
#
#                                        ssid  \
# 81805  984ab1d3-0ab9-4dfe-bdaa-021e639cc1ef
# 81887  984ab1d3-0ab9-4dfe-bdaa-021e639cc1ef
# 81920  984ab1d3-0ab9-4dfe-bdaa-021e639cc1ef
#
#                                       szrid  tBuf  tIBuf  tLBuf  tPld  tVH  \
# 81805  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
# 81887  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
# 81920  0e7f47ec-fd4c-446b-888b-e5cd29a45351     0      0      0     0    0
#
#                                         tid       type            uid  churn
# 81805  0450b5c2-12b6-46ce-8dc3-5aae2938d04b         vh  WUCH155102337  False
# 81887  0450b5c2-12b6-46ce-8dc3-5aae2938d04b  mplyevent  WUCH155102337  False
# ...

# %%
for uid in uid_lst[:20]:
    print '**'*10,'uid: ',uid,'**'*20
    uid_tid_grouped_rmv_tid_Uns = uid_grouped_rmv_tid_Uns.get_group(uid).groupby('tid')
    uid_tid_lst = uid_tid_grouped_rmv_tid_Uns.groups.keys()
    for tid in uid_tid_lst:
        if uid_tid_grouped_rmv_tid_Uns.get_group(tid).shape[0]!=1:
            print uid_tid_grouped_rmv_tid_Uns.get_group(tid)
            print '=='*40
# Out:
# ******************** uid:  WUCH155102022 ****************************************
#                           ts2      drt errmsg mplyevnt   spos  \
# 44113 2017-04-22 23:45:02.299  3410000    NaN    brchg  L2346
# 44360 2017-04-22 23:45:07.305  6010000    NaN    brchg  V0043
# 44958 2017-04-22 23:45:22.322        0    NaN      NaN  V0000
# 45291 2017-04-22 23:45:32.334        0    NaN      NaN  V0008
# 45783 2017-04-22 23:45:42.345        0    NaN      NaN    NaN
#
#                                        ssid  \
# 44113  07a97642-ed6f-4d31-9230-96c3cda95032
# 44360  07a97642-ed6f-4d31-9230-96c3cda95032
# 44958  07a97642-ed6f-4d31-9230-96c3cda95032
# 45291  07a97642-ed6f-4d31-9230-96c3cda95032
# 45783  07a97642-ed6f-4d31-9230-96c3cda95032
#
#                                       szrid  tBuf  tIBuf  tLBuf  tPld    tVH  \
# 44113  172ad403-e70c-4ce7-84d0-392fe745ddcf   806      0   5003     0   8046
# 44360  172ad403-e70c-4ce7-84d0-392fe745ddcf     0      0   5004     0  32326
# ...

# %%
# Out:
#         br  brn  brv chn                ckey             co       ct devm  \
# 81805  NaN  NaN  NaN      17943e6c6eec49cdb6  United States  unknown  NaN
# 81887  NaN  NaN  NaN      17943e6c6eec49cdb6  United States  unknown  NaN
# 81920  NaN  NaN  NaN      17943e6c6eec49cdb6  United States  unknown  NaN
#
#       devv  drt  ...   tIBuf tLBuf tPld tVH  \
# 81805  NaN    0  ...       0     0    0   0
# 81887  NaN    0  ...       0     0    0   0
# 81920  NaN    0  ...       0     0    0   0
#
#                                         tid                     ts2  \
# 81805  0450b5c2-12b6-46ce-8dc3-5aae2938d04b 2017-05-10 23:52:59.633
# 81887  0450b5c2-12b6-46ce-8dc3-5aae2938d04b 2017-05-10 23:52:59.638
# 81920  0450b5c2-12b6-46ce-8dc3-5aae2938d04b 2017-05-10 23:52:59.847
#
#             type            uid    yob  churn
# 81805         vh  WUCH155102337  Unset  False
# 81887  mplyevent  WUCH155102337    NaN  False
# 81920        Buf  WUCH155102337    NaN  False
#
# ...
